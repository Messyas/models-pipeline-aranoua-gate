# %%
import cv2
import time
import requests
import re
import numpy as np
from typing import Optional
from ultralytics import YOLO
from sort.sort import Sort
from util import get_car, reader

BASE_URL     = "http://visaonestbackend-env.eba-25r2yw9h.us-east-2.elasticbeanstalk.com/cars"
DETECT_URL   = f"{BASE_URL}/detect"
RELEASE_PATH = "{plate}/release"  

CHAR_TO_DIGIT = {'O': '0', 'I': '1', 'J': '3', 'A': '4', 'G': '6', 'S': '5'}
DIGIT_TO_CHAR = {v: k for k, v in CHAR_TO_DIGIT.items()}

PLATE_REGEX = re.compile(r'^[A-Z]{3}[A-Z0-9]{4}$')

def normalize_plate(text: str) -> Optional[str]:
    cleaned = re.sub(r'[^A-Za-z0-9]', '', text).upper()
    if cleaned.startswith("BR"):
        cleaned = cleaned[2:]
    if len(cleaned) == 7 and PLATE_REGEX.fullmatch(cleaned):
        return cleaned
    return None

def extract_plate_text(thresh_img):
    for _, text, score in reader.readtext(thresh_img, detail=1):
        plate = normalize_plate(text)
        print(f" OCR raw = '{text}', normalizado = '{plate}', score = {score:.2f}")
        if plate:
            return plate
    return None

def is_registered(plate: str) -> bool:
    url = f"{BASE_URL}/{plate}"
    try:
        r = requests.get(url, timeout=5)
    except requests.RequestException as e:
        print(f"falha ao verificar registro da placa {plate}: {e}")
        return False
    if r.status_code == 200:
        print(f"placa {plate} ja cadastrada.")
        return True
    if r.status_code == 404:
        print(f"placa {plate} nao encontrada no cadastro.")
        return False
    print(f"codigo inesperado ao verificar {plate}: {r.status_code}")
    return False

def register_plate(track_id: int, plate: str):
    payload = {"trackId": track_id, "plate": plate}
    print(f"registrando placa {plate} (trackId={track_id})…")
    try:
        r = requests.post(DETECT_URL, json=payload, timeout=5)
        r.raise_for_status()
        print(f"placa {plate} cadastrada ({r.status_code}).")
    except requests.RequestException as e:
        print(f"falha ao cadastrar {plate}: {e}")

def release_plate(plate: str) -> bool:
    url = f"{BASE_URL}/{plate}/release"
    print(f"solicitando liberacao da placa {plate}…")
    try:
        r = requests.post(url, timeout=5)
        r.raise_for_status()
    except requests.RequestException as e:
        print(f"falha na liberacao de {plate}: {e}")
        return False

    resp_json = r.json()
    print(r.status_code, resp_json)

    allowed = resp_json.get("allowed", False)
    if allowed:
        print(f"placa {plate} liberada.")
        print("carro liberado, ativando portao")
    else:
        print(f"backend nao autorizou liberacaio de {plate}.")

    return allowed


def preprocess_crop(crop):
    gray = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray, None, fx=2, fy=2, interpolation=cv2.INTER_LINEAR)
    return cv2.adaptiveThreshold(
        gray, 255,
        cv2.ADAPTIVE_THRESH_MEAN_C,
        cv2.THRESH_BINARY_INV, 35, 15
    )

def main():
    veh_model = YOLO("yolov8n.pt")
    lp_model  = YOLO("/home/messyas/ml/jetson/placas-model/models/runs/yolov8n_lp/weights/best.pt")
    tracker   = Sort()

    cap = cv2.VideoCapture(0, cv2.CAP_V4L2)
    if not cap.isOpened():
        raise RuntimeError("Nao foi possivel abrir camera")

    DETECTION_INTERVAL = 5.0  # segundos
    last_detection = time.time() - DETECTION_INTERVAL

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                print("falha ao capturar frame")
                break

            cv2.imshow("Webcam", frame)
            if cv2.waitKey(1) & 0xFF == ord("q"):
                break

            now = time.time()
            if now - last_detection >= DETECTION_INTERVAL:
                last_detection = now
                print(f"\n=== execucao de deteccao em {time.strftime('%H:%M:%S')} ===")

                veh_results = veh_model(frame)[0]
                veh_boxes = [
                    b for b in veh_results.boxes.data.tolist()
                    if int(b[5]) in [2, 3, 5, 7]
                ]
 
                if veh_boxes:
                    dets = np.array([
                        [x1, y1, x2, y2, score]
                        for x1, y1, x2, y2, score, _ in veh_boxes
                    ], dtype=float)
                    tracks = tracker.update(dets)
                else:
                    tracks = []

                lp_results = lp_model(frame)[0]
                for box in lp_results.boxes.data.tolist():
                    x1, y1, x2, y2, score, _ = box
                    *_, track_id = get_car(box, tracks)
                    if track_id == -1:
                        continue

                    crop = frame[int(y1):int(y2), int(x1):int(x2)]
                    plate = extract_plate_text(preprocess_crop(crop))
                    if not plate:
                        print("nenhuma placa valida detectada")
                        continue

                    print(f"[PLACA] detectada: {plate}")

                    if not is_registered(plate):
                        register_plate(track_id, plate)
                    else:
                        release_plate(plate)

    except KeyboardInterrupt:
        print("Encerrado pelo usuario")
    finally:
        cap.release()
        cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# === execucao de deteccao em 09:59:31 ===
#
# 0: 480x640 (no detections), 4.3ms
# Speed: 1.5ms preprocess, 4.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 0.6ms preprocess, 5.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 09:59:36 ===
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 0.8ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 09:59:41 ===
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 09:59:46 ===
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 09:59:51 ===
#
# 0: 480x640 1 car, 4.6ms
# Speed: 1.1ms preprocess, 4.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 09:59:56 ===
#
# 0: 480x640 1 car, 1 oven, 5.4ms
# Speed: 0.8ms preprocess, 5.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 4.6ms
# Speed: 0.6ms preprocess, 4.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#  OCR raw = 'POxL62', normalizado = 'None', score = 0.23
# nenhuma placa valida detectada
#
# === execucao de deteccao em 10:00:01 ===
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 2.0ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 4.3ms
# Speed: 0.6ms preprocess, 4.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:00:06 ===
#
# 0: 480x640 1 cell phone, 5.6ms
# Speed: 1.0ms preprocess, 5.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:00:11 ===
#
# 0: 480x640 1 mouse, 1 cell phone, 6.1ms
# Speed: 0.8ms preprocess, 6.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 4.6ms
# Speed: 0.6ms preprocess, 4.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:00:16 ===
#
# 0: 480x640 2 cars, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 4.0ms
# Speed: 0.6ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#  OCR raw = 'POX4G21', normalizado = 'POX4G21', score = 0.77
# [PLACA] detectada: POX4G21
# placa POX4G21 nao encontrada no cadastro.
# registrando placa POX4G21 (trackId=3.0)…
# placa POX4G21 cadastrada (200).
#
# === execucao de deteccao em 10:00:21 ===
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:00:26 ===
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 0.8ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:00:31 ===
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 0.7ms preprocess, 5.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 1.4ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:00:37 ===
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 1.1ms preprocess, 4.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:00:42 ===
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 1.1ms preprocess, 4.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:00:47 ===
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:00:52 ===
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 0.8ms preprocess, 5.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:00:57 ===
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:01:02 ===
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 0.7ms preprocess, 4.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 0.6ms preprocess, 4.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:01:07 ===
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:01:12 ===
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 0.9ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 0.6ms preprocess, 4.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execucao de deteccao em 10:01:17 ===
#
# 0: 480x640 (no detections), 5.4ms
# Speed: 0.8ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 0.6ms preprocess, 4.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# Encerrado pelo usuario

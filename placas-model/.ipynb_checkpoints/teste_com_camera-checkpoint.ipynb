# %%
import cv2
import time
import requests
import re
import numpy as np
from typing import Optional
from ultralytics import YOLO
from sort.sort import Sort
from util import get_car, reader

BASE_URL     = "http://visaonestbackend-env.eba-25r2yw9h.us-east-2.elasticbeanstalk.com/cars"
DETECT_URL   = f"{BASE_URL}/detect"
RELEASE_PATH = "{plate}/release"  

CHAR_TO_DIGIT = {'O': '0', 'I': '1', 'J': '3', 'A': '4', 'G': '6', 'S': '5'}
DIGIT_TO_CHAR = {v: k for k, v in CHAR_TO_DIGIT.items()}

PLATE_REGEX = re.compile(r'^[A-Z]{3}[A-Z0-9]{4}$')

def normalize_plate(text: str) -> Optional[str]:
    cleaned = re.sub(r'[^A-Za-z0-9]', '', text).upper()
    if cleaned.startswith("BR"):
        cleaned = cleaned[2:]
    if len(cleaned) == 7 and PLATE_REGEX.fullmatch(cleaned):
        return cleaned
    return None

def extract_plate_text(thresh_img):
    for _, text, score in reader.readtext(thresh_img, detail=1):
        plate = normalize_plate(text)
        print(f" OCR raw = '{text}', normalizado = '{plate}', score = {score:.2f}")
        if plate:
            return plate
    return None

def is_registered(plate: str) -> bool:
    url = f"{BASE_URL}/{plate}"
    try:
        r = requests.get(url, timeout=5)
    except requests.RequestException as e:
        print(f"falha ao verificar registro da placa {plate}: {e}")
        return False
    if r.status_code == 200:
        print(f"placa {plate} ja cadastrada.")
        return True
    if r.status_code == 404:
        print(f"placa {plate} nao encontrada no cadastro.")
        return False
    print(f"codigo inesperado ao verificar {plate}: {r.status_code}")
    return False

def register_plate(track_id: int, plate: str):
    payload = {"trackId": track_id, "plate": plate}
    print(f"registrando placa {plate} (trackId={track_id})…")
    try:
        r = requests.post(DETECT_URL, json=payload, timeout=5)
        r.raise_for_status()
        print(f"placa {plate} cadastrada ({r.status_code}).")
    except requests.RequestException as e:
        print(f"falha ao cadastrar {plate}: {e}")

def release_plate(plate: str) -> bool:
    url = f"{BASE_URL}/{plate}/release"
    print(f"solicitando liberacao da placa {plate}…")
    try:
        r = requests.post(url, timeout=5)
        r.raise_for_status()
    except requests.RequestException as e:
        print(f"falha na liberacao de {plate}: {e}")
        return False

    resp_json = r.json()
    print(r.status_code, resp_json)

    allowed = resp_json.get("allowed", False)
    if allowed:
        print(f"placa {plate} liberada.")
        print("carro liberado, ativando portao")
    else:
        print(f"backend nao autorizou liberacaio de {plate}.")

    return allowed


def preprocess_crop(crop):
    gray = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray, None, fx=2, fy=2, interpolation=cv2.INTER_LINEAR)
    return cv2.adaptiveThreshold(
        gray, 255,
        cv2.ADAPTIVE_THRESH_MEAN_C,
        cv2.THRESH_BINARY_INV, 35, 15
    )

def main():
    veh_model = YOLO("yolov8n.pt")
    lp_model  = YOLO("/home/messyas/ml/jetson/placas-model/models/runs/yolov8n_lp/weights/best.pt")
    tracker   = Sort()

    cap = cv2.VideoCapture(0, cv2.CAP_V4L2)
    if not cap.isOpened():
        raise RuntimeError("Nao foi possivel abrir camera")

    DETECTION_INTERVAL = 5.0  # segundos
    last_detection = time.time() - DETECTION_INTERVAL

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                print("falha ao capturar frame")
                break

            cv2.imshow("Webcam", frame)
            if cv2.waitKey(1) & 0xFF == ord("q"):
                break

            now = time.time()
            if now - last_detection >= DETECTION_INTERVAL:
                last_detection = now
                print(f"\n=== execucao de deteccao em {time.strftime('%H:%M:%S')} ===")

                veh_results = veh_model(frame)[0]
                veh_boxes = [
                    b for b in veh_results.boxes.data.tolist()
                    if int(b[5]) in [2, 3, 5, 7]
                ]
 
                if veh_boxes:
                    dets = np.array([
                        [x1, y1, x2, y2, score]
                        for x1, y1, x2, y2, score, _ in veh_boxes
                    ], dtype=float)
                    tracks = tracker.update(dets)
                else:
                    tracks = []

                lp_results = lp_model(frame)[0]
                for box in lp_results.boxes.data.tolist():
                    x1, y1, x2, y2, score, _ = box
                    *_, track_id = get_car(box, tracks)
                    if track_id == -1:
                        continue

                    crop = frame[int(y1):int(y2), int(x1):int(x2)]
                    plate = extract_plate_text(preprocess_crop(crop))
                    if not plate:
                        print("nenhuma placa valida detectada")
                        continue

                    print(f"[PLACA] detectada: {plate}")

                    if not is_registered(plate):
                        register_plate(track_id, plate)
                    else:
                        release_plate(plate)

    except KeyboardInterrupt:
        print("Encerrado pelo usuario")
    finally:
        cap.release()
        cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# === execução de detecção em 22:12:17 ===
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 0.6ms preprocess, 4.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 0.6ms preprocess, 4.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:12:22 ===
#
# 0: 480x640 1 keyboard, 5.7ms
# Speed: 1.2ms preprocess, 5.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 0.6ms preprocess, 4.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:12:27 ===
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 1.1ms preprocess, 4.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:12:32 ===
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 0.6ms preprocess, 4.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:12:37 ===
#
# 0: 480x640 1 keyboard, 5.0ms
# Speed: 0.8ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 0.6ms preprocess, 4.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:12:42 ===
#
# 0: 480x640 1 car, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 4.9ms
# Speed: 0.6ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#  OCR raw = '7735', normalizado = 'None', score = 0.05
#  OCR raw = '.RHL9196', normalizado = 'RHL9196', score = 0.49
# [PLACA] detectada: RHL9196
# [INFO] placa RHL9196 não encontrada no cadastro.
# [AÇÃO] registrando placa RHL9196 (trackId=1.0)…
# [SUCESSO] placa RHL9196 cadastrada (200).
#
# === execução de detecção em 22:12:47 ===
#
# 0: 480x640 1 car, 5.0ms
# Speed: 1.4ms preprocess, 5.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 4.8ms
# Speed: 0.7ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#  OCR raw = '3', normalizado = 'None', score = 0.15
#  OCR raw = 'C', normalizado = 'None', score = 0.16
#  OCR raw = ''RML9I96', normalizado = 'RML9I96', score = 0.22
# [PLACA] detectada: RML9I96
# [INFO] placa RML9I96 não encontrada no cadastro.
# [AÇÃO] registrando placa RML9I96 (trackId=1.0)…
# [SUCESSO] placa RML9I96 cadastrada (200).
#
# === execução de detecção em 22:12:52 ===
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 1.4ms preprocess, 4.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:12:57 ===
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:13:02 ===
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 0.7ms preprocess, 5.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:13:07 ===
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 1.1ms preprocess, 4.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:13:12 ===
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 0.8ms preprocess, 5.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 0.7ms preprocess, 5.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:13:18 ===
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 1.0ms preprocess, 4.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 0.8ms preprocess, 5.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:13:23 ===
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 1.1ms preprocess, 4.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 2.2ms preprocess, 4.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:13:28 ===
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:13:33 ===
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 1.0ms preprocess, 4.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:13:38 ===
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 1.0ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:13:43 ===
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 0.6ms preprocess, 4.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:13:48 ===
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 0.6ms preprocess, 4.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:13:53 ===
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 0.6ms preprocess, 4.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:13:58 ===
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 0.7ms preprocess, 4.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:14:03 ===
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 1.0ms preprocess, 4.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:14:08 ===
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:14:13 ===
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 0.8ms preprocess, 5.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:14:18 ===
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 0.7ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:14:23 ===
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 1.1ms preprocess, 4.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:14:28 ===
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 0.8ms preprocess, 5.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:14:33 ===
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 1.1ms preprocess, 4.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:14:38 ===
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 1.1ms preprocess, 4.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:14:43 ===
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 0.7ms preprocess, 5.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:14:48 ===
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 0.8ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 0.7ms preprocess, 4.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:14:53 ===
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 1.0ms preprocess, 4.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:14:58 ===
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 0.5ms preprocess, 4.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:15:03 ===
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.3ms
# Speed: 1.0ms preprocess, 4.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:15:08 ===
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 1.1ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:15:13 ===
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.3ms
# Speed: 0.9ms preprocess, 4.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:15:18 ===
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 0.7ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:15:23 ===
#
# 0: 480x640 (no detections), 4.3ms
# Speed: 1.0ms preprocess, 4.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.0ms
# Speed: 1.1ms preprocess, 4.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:15:28 ===
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 1.0ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:15:33 ===
#
# 0: 480x640 (no detections), 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.8ms
# Speed: 0.8ms preprocess, 5.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:15:38 ===
#
# 0: 480x640 (no detections), 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# === execução de detecção em 22:15:44 ===
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 0.8ms preprocess, 5.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.3ms
# Speed: 1.8ms preprocess, 4.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# Encerrado pelo usuário.
